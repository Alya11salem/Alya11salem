# %% [markdown]
# <a href="https://colab.research.google.com/github/Alya11salem/Alya11salem/blob/main/Matplotlib_Pair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome!

# %% [markdown]
# #### #1. Import Pandas, `Matplotlib.pyplot`, and NumPy. Don't forget the line that makes `matplotlib` render in a Jupyter Notebook!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df = pd.read_csv("NBA_players_2015.csv")
nba_df
# Out:
#      season_end          player pos  age  ... OBPM  DBPM  BPM  VORP
# 0          2015      Quincy Acy   F   24  ... -2.6  -0.7 -3.4  -0.3
# 1          2015    Jordan Adams   G   20  ... -2.3   1.8 -0.5   0.0
# 2          2015    Steven Adams   C   21  ... -2.0   2.0 -0.1   0.6
# 3          2015     Jeff Adrien   F   28  ... -2.6   0.8 -1.8   0.0
# 4          2015   Arron Afflalo   G   29  ... -0.2  -1.4 -1.6   0.2
# ..          ...             ...  ..  ...  ...  ...   ...  ...   ...
# 473        2015     James Young   G   19  ... -1.9  -2.2 -4.1  -0.2
# 474        2015      Nick Young   G   29  ...  1.0  -4.2 -3.2  -0.3
# 475        2015  Thaddeus Young   F   26  ...  0.4  -0.1  0.3   1.1
# 476        2015     Cody Zeller   C   22  ... -1.9   2.5  0.7   1.0
# 477        2015    Tyler Zeller   C   25  ...  0.2   0.4  0.7   0.9
#
# [478 rows x 49 columns]

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
nba_df.head()
# Out:
#    season_end         player pos  age  ... OBPM  DBPM  BPM  VORP
# 0        2015     Quincy Acy   F   24  ... -2.6  -0.7 -3.4  -0.3
# 1        2015   Jordan Adams   G   20  ... -2.3   1.8 -0.5   0.0
# 2        2015   Steven Adams   C   21  ... -2.0   2.0 -0.1   0.6
# 3        2015    Jeff Adrien   F   28  ... -2.6   0.8 -1.8   0.0
# 4        2015  Arron Afflalo   G   29  ... -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %%
nba_df.hist('age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7a8ae9710>]],
#       dtype=object)

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to `20`.

# %%
nba_df.hist('age').bns=20
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-6bd959b5bbe9> in <module>()
# ----> 1 nba_df.hist('age').bns=20
#
# AttributeError: 'numpy.ndarray' object has no attribute 'bns'

# %% [markdown]
# #### #6. Is there a relathionship between age & games number g?.

# %%
 plt.scatter(nba_df.age,nba_df.g);
 ### by sccatter plot

# %% [markdown]
# # #7.Create a bar chart of team_id by age.

# %%
plt.bar(nba_df.bref_team_id,nba_df.age);

# %% [markdown]
# #### #8. Examine the distribution of age without using histogram

# %% [markdown]
# #### #9. Create a line plot for the ages of the players.

# %% [markdown]
# #### #10. Is there a relathionship between mp & fg? If so, is it positive or negative correlation?

# %%
plt.scatter(nba_df.mp,nba_df.fg);

# %% [markdown]
# # The end!
